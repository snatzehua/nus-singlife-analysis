# %%
import pandas as pd

# Load datasets
agents = pd.read_excel("/Users/snatzehua/Downloads/nus_agent_info_df.xlsx")
policies = pd.read_excel("/Users/snatzehua/Downloads/nus_policy_info_df.xlsx")
clients = pd.read_excel("/Users/snatzehua/Downloads/nus_client_info_df.xlsx")

# Show all columns
pd.set_option('display.max_columns', None)

# %%
merged_df = pd.merge(policies, agents, on="agntnum", how="left")
merged_df = pd.merge(merged_df, clients, on="secuityno", how="left")

merged_df.head()
# Out:
#     chdrnum agntnum  secuityno    occdate  annual_premium product  flg_main  \
# 0   PID:281  AIN:62   CIN:6957 2018-11-12             0.0  prod_8         1
# 1   PID:280  AIN:63   CIN:2161 2024-02-22             7.0  prod_8         1
# 2  PID:2577  AIN:63  CIN:16605 2024-08-28           423.0  prod_6         1
# 3  PID:2578  AIN:63  CIN:16605 2024-08-27           217.0  prod_6         1
# 4   PID:305  AIN:63   CIN:7917 2024-08-28           432.0  prod_6         1
#
#    flg_rider  flg_inforce  flg_lapsed  flg_cancel  flg_expire  flg_converted  \
# 0          0            1           0           0           0              1
# 1          0            1           0           0           0              1
# 2          0            1           0           0           0              1
# 3          0            1           0           0           0              1
# 4          0            1           0           0           0              1
#
#   product_grp cust_age_at_purchase_grp cust_tenure_at_purchase_grp  agent_age  \
# 0        PG:0              AG05_35to39                  TNR2_lt1yr       31.0
# 1        PG:0              AG04_30to34                 TNR4_4to8yr       32.0
# 2        PG:0              AG08_50to54                  TNR5_8yrup       32.0
# 3        PG:0              AG08_50to54                  TNR5_8yrup       32.0
# 4        PG:0              AG07_45to49                 TNR4_4to8yr       32.0
#
#   agent_gender agent_marital  agent_tenure  cnt_converted  \
# 0            M             S             6             47
# 1            M             S            71           4560
# 2            M             S            71           4560
# 3            M             S            71           4560
# 4            M             S            71           4560
#
#    annual_premium_cnvrt  pct_lapsed  pct_cancel  pct_inforce  \
# 0              6112.000         0.1    0.243689     0.936170
# 1           1045929.756         0.1    0.157312     0.854605
# 2           1045929.756         0.1    0.157312     0.854605
# 3           1045929.756         0.1    0.157312     0.854605
# 4           1045929.756         0.1    0.157312     0.854605
#
#    pct_prod_0_cnvrt  pct_prod_1_cnvrt  pct_prod_2_cnvrt  pct_prod_3_cnvrt  \
# 0               0.0          0.212766          0.319149               0.0
# 1               0.0          0.041009          0.051974               0.0
# 2               0.0          0.041009          0.051974               0.0
# 3               0.0          0.041009          0.051974               0.0
# 4               0.0          0.041009          0.051974               0.0
#
#    pct_prod_4_cnvrt  pct_prod_5_cnvrt  pct_prod_6_cnvrt  pct_prod_7_cnvrt  \
# 0          0.000000          0.000000          0.042553          0.000000
# 1          0.010307          0.033333          0.063596          0.007237
# 2          0.010307          0.033333          0.063596          0.007237
# 3          0.010307          0.033333          0.063596          0.007237
# 4          0.010307          0.033333          0.063596          0.007237
#
#    pct_prod_8_cnvrt  pct_prod_9_cnvrt  pct_SX0_unknown  pct_SX1_male  \
# 0          0.425532           0.00000         0.042553      0.531915
# 1          0.761404           0.03114         0.024561      0.605263
# 2          0.761404           0.03114         0.024561      0.605263
# 3          0.761404           0.03114         0.024561      0.605263
# 4          0.761404           0.03114         0.024561      0.605263
#
#    pct_SX2_female  pct_AG01_lt20  pct_AG02_20to24  pct_AG03_25to29  \
# 0        0.425532       0.000000         0.000000         0.106383
# 1        0.370175       0.009649         0.022149         0.050439
# 2        0.370175       0.009649         0.022149         0.050439
# 3        0.370175       0.009649         0.022149         0.050439
# 4        0.370175       0.009649         0.022149         0.050439
#
#    pct_AG04_30to34  pct_AG05_35to39  pct_AG06_40to44  pct_AG07_45to49  \
# 0         0.148936         0.297872         0.148936         0.191489
# 1         0.260307         0.212719         0.181360         0.121711
# 2         0.260307         0.212719         0.181360         0.121711
# 3         0.260307         0.212719         0.181360         0.121711
# 4         0.260307         0.212719         0.181360         0.121711
#
#    pct_AG08_50to54  pct_AG09_55to59  pct_AG10_60up  cluster  \
# 0         0.000000         0.000000       0.000000        1
# 1         0.071711         0.019956       0.011842        1
# 2         0.071711         0.019956       0.011842        1
# 3         0.071711         0.019956       0.011842        1
# 4         0.071711         0.019956       0.011842        1
#
#                              agent_product_expertise cltsex     cltdob marryd  \
# 0              ['prod_9' 'prod_2' 'prod_0' 'prod_0']      F 1982-03-11      M
# 1  ['prod_0' 'prod_9' 'prod_9' 'prod_6' 'prod_0' ...      M 1991-03-18      S
# 2  ['prod_0' 'prod_9' 'prod_9' 'prod_6' 'prod_0' ...      M 1973-04-16      M
# 3  ['prod_0' 'prod_9' 'prod_9' 'prod_6' 'prod_0' ...      M 1973-04-16      M
# 4  ['prod_0' 'prod_9' 'prod_9' 'prod_6' 'prod_0' ...      F 1978-06-20      M
#
#   race_desc_map cltpcode  household_size  economic_status  family_size  \
# 0       Chinese   648146            25.0             78.0         98.0
# 1       Chinese   680120            57.0             31.0         47.0
# 2       Chinese   640818            56.0             30.0         60.0
# 3       Chinese   640818            56.0             30.0         60.0
# 4         Malay   760401            23.0              0.0         55.0
#
#   household_size_grp family_size_grp
# 0           HH1_lt40        FS5_80up
# 1         HH2_40to80      FS3_40to60
# 2         HH2_40to80      FS4_60to80
# 3         HH2_40to80      FS4_60to80
# 4           HH1_lt40      FS3_40to60

# %%
# Map age groups to number
age_mapping = {
    "AG01_lt20": 17, "AG02_20to24": 22, "AG03_25to29": 27, "AG04_30to34": 32,
    "AG05_35to39": 37, "AG06_40to44": 42, "AG07_45to49": 47, "AG08_50to54": 52,
    "AG09_55to59": 57, "AG10_60up": 62
}
merged_df["cltage"] = merged_df["cust_age_at_purchase_grp"].map(age_mapping)

# Add median to all missing values if possible
columns_to_fix = ["agent_age", "household_size", "economic_status", "family_size", "cltage"]
median_values = {col: merged_df[col].median() for col in columns_to_fix}
merged_df.fillna(median_values, inplace=True)

# Map gender to numerical values
cltsex_map = {"M": 1, "F": 0, " ": 0.5}
agent_gender_map = {"M": 1, "F": 0, "U": 0.5}
merged_df["cltsex"] = merged_df["cltsex"].map(cltsex_map).fillna(0.5)
merged_df["agent_gender"] = merged_df["agent_gender"].map(cltsex_map).fillna(0.5)

# Drop rows where key fields have NaNs (cannot be filled)
merged_df.dropna(subset=["cltdob", "cltpcode"], inplace=True)

# %%
import pandas as pd
import numpy as np
import torch
from torch import nn
from sklearn.preprocessing import MinMaxScaler, LabelEncoder

# X Variables
X_continuous_vars = ["cltsex", "cltage", "household_size", "economic_status", "family_size"]
X_categorical_vars = ["product", "product_grp", "race_desc_map"]
X_percentage_vars = []

# Define the target variable
target_var = "agntnum"

# Drop columns not in the above lists
X_all_vars = X_continuous_vars + X_categorical_vars + X_percentage_vars
all_vars = X_all_vars + [target_var]
df = merged_df.drop(columns=[col for col in merged_df.columns if col not in all_vars])

### --- Step 1: Keep Percentage Variables Unchanged ---
X_percentage = df[X_percentage_vars] if X_percentage_vars else pd.DataFrame(index=df.index)

### --- Step 2: Apply Min-Max Scaling (0-1) to Continuous Variables ---
X_scaler = MinMaxScaler()
X_continuous = pd.DataFrame(X_scaler.fit_transform(df[X_continuous_vars]), 
                            columns=X_continuous_vars, 
                            index=df.index)

### --- Step 3: Label Encoding for Categorical Variables ---
label_encoders = {}
for col in X_categorical_vars:
    le = LabelEncoder()
    df[col] = le.fit_transform(df[col])  # Convert categorical to numerical labels
    label_encoders[col] = le  # Store encoders for future use

X_categorical = df[X_categorical_vars]

### --- Step 4: Combine All Processed Features ---
X_final = pd.concat([X_continuous, X_percentage, X_categorical], axis=1)

### --- Step 5: Encode Target Variable (agntnum) for Classification ---
label_encoder = LabelEncoder()
Y_final = label_encoder.fit_transform(df[target_var])  # Convert categorical labels to integers

# Convert to PyTorch tensors
X_tensor = torch.tensor(X_final.values, dtype=torch.float32)
Y_tensor = torch.tensor(Y_final, dtype=torch.long)  # Classification targets should be long

# Print final tensor shapes
print("X Tensor Shape:", X_tensor.shape)
print("Y Tensor Shape:", Y_tensor.shape)
print("Unique Classes in Y:", len(np.unique(Y_final)))  # Debugging: Check class distribution
# Out:
# X Tensor Shape: torch.Size([29263, 8])
# Y Tensor Shape: torch.Size([29263])
# Unique Classes in Y: 10018

# %%
import pandas as pd
import numpy as np
import torch
from torch import nn
from sklearn.preprocessing import MinMaxScaler, LabelEncoder

# Define X labels
X_numerical_cols = ["cltage", "cltsex", "agent_age", "household_size", "economic_status", "family_size"]

# Define Y labels
Y = ["agntnum"]

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset, random_split
import matplotlib.pyplot as plt

# Set device (use GPU if available)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Set random seed for reproducibility
torch.manual_seed(41)

# Convert DataFrame to PyTorch Tensors
X_tensor = torch.tensor(X_final.values, dtype=torch.float32)
Y_tensor = torch.tensor(df['agntnum'].astype('category').cat.codes.values, dtype=torch.long)

# Move tensors to the chosen device (CPU/GPU)
X_tensor, Y_tensor = X_tensor.to(device), Y_tensor.to(device)

# Split into Train and Test Sets
train_size = int(0.8 * len(X_tensor))
test_size = len(X_tensor) - train_size
train_dataset, test_dataset = random_split(TensorDataset(X_tensor, Y_tensor), [train_size, test_size])

train_loader = DataLoader(train_dataset, batch_size=64, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=64, shuffle=False)

# Define Neural Network Model
class NeuralNetwork(nn.Module):
    def __init__(self, input_size, output_size):
        super(NeuralNetwork, self).__init__()
        self.fc1 = nn.Linear(input_size, 128)
        self.bn1 = nn.BatchNorm1d(128)
        self.relu1 = nn.ReLU()
        
        self.fc2 = nn.Linear(128, 64)
        self.bn2 = nn.BatchNorm1d(64)
        self.relu2 = nn.ReLU()

        self.fc3 = nn.Linear(64, 32)
        self.relu3 = nn.ReLU()

        self.fc4 = nn.Linear(32, output_size)  # No activation for logits
        
    def forward(self, x):
        x = self.relu1(self.bn1(self.fc1(x)))
        x = self.relu2(self.bn2(self.fc2(x)))
        x = self.relu3(self.fc3(x))
        x = self.fc4(x)
        return x

# Initialize Model
input_size = X_final.shape[1]
output_size = len(df['agntnum'].astype('category').cat.categories)
model = NeuralNetwork(input_size, output_size).to(device)

# Apply Xavier Initialization
def initialize_weights(m):
    if isinstance(m, nn.Linear):
        nn.init.xavier_uniform_(m.weight)
        nn.init.zeros_(m.bias)

model.apply(initialize_weights)

# Compute Class Weights for Imbalanced Dataset
class_counts = df['agntnum'].value_counts().sort_index().values
class_weights = torch.tensor(1.0 / (class_counts / class_counts.sum()), dtype=torch.float32).to(device)

# Define Focal Loss
class FocalLoss(nn.Module):
    def __init__(self, alpha=None, gamma=2.0):
        super(FocalLoss, self).__init__()
        self.alpha = alpha  # Class weights
        self.gamma = gamma  # Focus parameter

    def forward(self, logits, targets):
        ce_loss = nn.CrossEntropyLoss(weight=self.alpha)(logits, targets)
        pt = torch.exp(-ce_loss)  # Compute pt
        focal_loss = (1 - pt) ** self.gamma * ce_loss  # Apply focal factor
        return focal_loss.mean()

# Define Loss Function with Class Weights
loss_function = FocalLoss(alpha=class_weights.to(device))

# Define Optimizer with Lower Learning Rate
optimizer = optim.AdamW(model.parameters(), lr=0.001, weight_decay=0.01)
# scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='min', factor=0.5, patience=5, verbose=True)
scheduler = optim.lr_scheduler.ExponentialLR(optimizer, gamma=0.97)

# Training Loop
loss_history = []
top1_accuracy_history = []
top3_accuracy_history = []
epochs = 300
best_loss = float('inf')
patience = 10
counter = 0

for epoch in range(epochs):
    model.train()
    epoch_loss = 0
    for batch_X, batch_y in train_loader:
        batch_X, batch_y = batch_X.to(device), batch_y.to(device)  # Move batch to device

        optimizer.zero_grad()
        predictions = model(batch_X)
        loss = loss_function(predictions, batch_y)
        loss.backward()
        optimizer.step()
        epoch_loss += loss.item()
    
    avg_loss = epoch_loss / len(train_loader)
    loss_history.append(avg_loss)

    # Evaluate Model on Test Set after Each Epoch (Top-1 & Top-3 Accuracy)
    model.eval()
    correct_top1 = 0
    correct_top3 = 0
    total = 0
    with torch.no_grad():
        for batch_X, batch_y in test_loader:
            batch_X, batch_y = batch_X.to(device), batch_y.to(device)  # Move batch to device
            outputs = model(batch_X)

            # Top-1 Accuracy
            _, predicted_top1 = torch.max(outputs, 1)
            correct_top1 += (predicted_top1 == batch_y).sum().item()

            # Top-3 Accuracy
            top3_preds = torch.topk(outputs, 3, dim=1).indices  # Get top 3 predictions
            correct_top3 += sum(batch_y[i] in top3_preds[i] for i in range(len(batch_y)))

            total += batch_y.size(0)

    top1_accuracy = 100 * correct_top1 / total
    top3_accuracy = 100 * correct_top3 / total
    top1_accuracy_history.append(top1_accuracy)
    top3_accuracy_history.append(top3_accuracy)

    print(f"Epoch [{epoch+1}/{epochs}], Avg Loss: {avg_loss:.4f}, Top-1 Accuracy: {top1_accuracy:.2f}%, Top-3 Accuracy: {top3_accuracy:.2f}%")

    # Early Stopping Check
    if avg_loss < best_loss:
        best_loss = avg_loss
        counter = 0
    else:
        counter += 1
        if counter >= patience:
            print("Early stopping triggered")
            break
    
    # Adjust learning rate based on loss
    scheduler.step(avg_loss)

# Final Evaluation on Test Set
print(f"Final Top-1 Accuracy: {top1_accuracy:.2f}%")
print(f"Final Top-3 Accuracy: {top3_accuracy:.2f}%")

# Plot Loss Curve
plt.figure(figsize=(10,5))
plt.subplot(1,2,1)
plt.plot(range(1, len(loss_history) + 1), loss_history, marker='o', label="Loss")
plt.xlabel('Epoch')
plt.ylabel('Average Loss')
plt.title('Training Loss Over Epochs')
plt.legend()
plt.grid()

# Plot Accuracy Curves
plt.subplot(1,2,2)
plt.plot(range(1, len(top1_accuracy_history) + 1), top1_accuracy_history, marker='o', label="Top-1 Accuracy", color='r')
plt.plot(range(1, len(top3_accuracy_history) + 1), top3_accuracy_history, marker='o', label="Top-3 Accuracy", color='g')
plt.xlabel('Epoch')
plt.ylabel('Accuracy (%)')
plt.title('Test Accuracy Over Epochs')
plt.legend()
plt.grid()

plt.tight_layout()
plt.show()

# Save Model
torch.save(model.state_dict(), 'neural_network.pth')
print("Model training complete and saved!")
# Out:
# Epoch [1/300], Avg Loss: 9.2339, Top-1 Accuracy: 0.10%, Top-3 Accuracy: 0.31%
# /Users/snatzehua/Documents/GitHub/nus-singlife-analysis/venv/lib/python3.12/site-packages/torch/optim/lr_scheduler.py:243: UserWarning: The epoch parameter in `scheduler.step()` was not necessary and is being deprecated where possible. Please use `scheduler.step()` to step the scheduler. During the deprecation, if epoch is different from None, the closed form is used instead of the new chainable form, where available. Please open an issue if you are unable to replicate your use case: https://github.com/pytorch/pytorch/issues/new/choose.
#   warnings.warn(EPOCH_DEPRECATION_WARNING, UserWarning)
# Epoch [2/300], Avg Loss: 8.6739, Top-1 Accuracy: 0.09%, Top-3 Accuracy: 0.29%
# Epoch [3/300], Avg Loss: 8.0000, Top-1 Accuracy: 0.14%, Top-3 Accuracy: 0.38%
# Epoch [4/300], Avg Loss: 7.3359, Top-1 Accuracy: 0.24%, Top-3 Accuracy: 0.72%
# Epoch [5/300], Avg Loss: 6.7450, Top-1 Accuracy: 0.48%, Top-3 Accuracy: 0.97%
# Epoch [6/300], Avg Loss: 6.2033, Top-1 Accuracy: 0.65%, Top-3 Accuracy: 1.55%
# Epoch [7/300], Avg Loss: 5.7429, Top-1 Accuracy: 1.04%, Top-3 Accuracy: 2.20%
# Epoch [8/300], Avg Loss: 5.3668, Top-1 Accuracy: 1.06%, Top-3 Accuracy: 2.60%
# Epoch [9/300], Avg Loss: 5.0754, Top-1 Accuracy: 1.32%, Top-3 Accuracy: 2.97%
# Epoch [10/300], Avg Loss: 4.8369, Top-1 Accuracy: 1.44%, Top-3 Accuracy: 3.79%
# Epoch [11/300], Avg Loss: 4.6455, Top-1 Accuracy: 1.78%, Top-3 Accuracy: 3.88%
# Epoch [12/300], Avg Loss: 4.5260, Top-1 Accuracy: 1.86%, Top-3 Accuracy: 4.39%
# Epoch [13/300], Avg Loss: 4.3843, Top-1 Accuracy: 2.15%, Top-3 Accuracy: 4.66%
# Epoch [14/300], Avg Loss: 4.2683, Top-1 Accuracy: 2.32%, Top-3 Accuracy: 5.04%
# Epoch [15/300], Avg Loss: 4.1600, Top-1 Accuracy: 2.53%, Top-3 Accuracy: 5.57%
# Epoch [16/300], Avg Loss: 4.0818, Top-1 Accuracy: 2.61%, Top-3 Accuracy: 5.98%
# Epoch [17/300], Avg Loss: 3.9851, Top-1 Accuracy: 2.68%, Top-3 Accuracy: 6.15%
# Epoch [18/300], Avg Loss: 3.9261, Top-1 Accuracy: 3.16%, Top-3 Accuracy: 6.44%
# Epoch [19/300], Avg Loss: 3.8432, Top-1 Accuracy: 3.47%, Top-3 Accuracy: 6.92%
# Epoch [20/300], Avg Loss: 3.7809, Top-1 Accuracy: 3.55%, Top-3 Accuracy: 7.40%
# Epoch [21/300], Avg Loss: 3.7064, Top-1 Accuracy: 3.81%, Top-3 Accuracy: 7.43%
# Epoch [22/300], Avg Loss: 3.6238, Top-1 Accuracy: 3.83%, Top-3 Accuracy: 7.67%
# Epoch [23/300], Avg Loss: 3.5741, Top-1 Accuracy: 4.34%, Top-3 Accuracy: 8.20%
# Epoch [24/300], Avg Loss: 3.5242, Top-1 Accuracy: 4.36%, Top-3 Accuracy: 8.06%
# Epoch [25/300], Avg Loss: 3.4734, Top-1 Accuracy: 4.49%, Top-3 Accuracy: 8.59%
# Epoch [26/300], Avg Loss: 3.4195, Top-1 Accuracy: 4.73%, Top-3 Accuracy: 8.94%
# Epoch [27/300], Avg Loss: 3.3691, Top-1 Accuracy: 5.21%, Top-3 Accuracy: 8.97%
# Epoch [28/300], Avg Loss: 3.3040, Top-1 Accuracy: 5.01%, Top-3 Accuracy: 9.24%
# Epoch [29/300], Avg Loss: 3.2639, Top-1 Accuracy: 5.38%, Top-3 Accuracy: 9.60%
# Epoch [30/300], Avg Loss: 3.2334, Top-1 Accuracy: 5.23%, Top-3 Accuracy: 9.47%
# Epoch [31/300], Avg Loss: 3.1673, Top-1 Accuracy: 5.43%, Top-3 Accuracy: 9.76%
# Epoch [32/300], Avg Loss: 3.1491, Top-1 Accuracy: 5.71%, Top-3 Accuracy: 10.03%
# Epoch [33/300], Avg Loss: 3.1222, Top-1 Accuracy: 5.81%, Top-3 Accuracy: 9.96%
# Epoch [34/300], Avg Loss: 3.0700, Top-1 Accuracy: 6.25%, Top-3 Accuracy: 10.30%
# Epoch [35/300], Avg Loss: 3.0226, Top-1 Accuracy: 5.86%, Top-3 Accuracy: 10.35%
# Epoch [36/300], Avg Loss: 2.9909, Top-1 Accuracy: 5.88%, Top-3 Accuracy: 10.27%
# Epoch [37/300], Avg Loss: 2.9599, Top-1 Accuracy: 6.32%, Top-3 Accuracy: 10.54%
# Epoch [38/300], Avg Loss: 2.9138, Top-1 Accuracy: 6.10%, Top-3 Accuracy: 10.81%
# Epoch [39/300], Avg Loss: 2.9026, Top-1 Accuracy: 6.30%, Top-3 Accuracy: 11.14%
# Epoch [40/300], Avg Loss: 2.8836, Top-1 Accuracy: 6.20%, Top-3 Accuracy: 10.68%
# Epoch [41/300], Avg Loss: 2.8348, Top-1 Accuracy: 6.53%, Top-3 Accuracy: 11.36%
# Epoch [42/300], Avg Loss: 2.8503, Top-1 Accuracy: 6.30%, Top-3 Accuracy: 10.90%
# Epoch [43/300], Avg Loss: 2.7839, Top-1 Accuracy: 6.68%, Top-3 Accuracy: 11.14%
# Epoch [44/300], Avg Loss: 2.7977, Top-1 Accuracy: 6.53%, Top-3 Accuracy: 11.17%
# Epoch [45/300], Avg Loss: 2.7358, Top-1 Accuracy: 7.00%, Top-3 Accuracy: 11.58%
# Epoch [46/300], Avg Loss: 2.7170, Top-1 Accuracy: 6.99%, Top-3 Accuracy: 11.46%
# Epoch [47/300], Avg Loss: 2.6927, Top-1 Accuracy: 6.99%, Top-3 Accuracy: 11.62%
# Epoch [48/300], Avg Loss: 2.6642, Top-1 Accuracy: 7.12%, Top-3 Accuracy: 11.79%
# Epoch [49/300], Avg Loss: 2.6418, Top-1 Accuracy: 6.99%, Top-3 Accuracy: 11.69%
# Epoch [50/300], Avg Loss: 2.6305, Top-1 Accuracy: 7.23%, Top-3 Accuracy: 11.84%
# Epoch [51/300], Avg Loss: 2.5976, Top-1 Accuracy: 7.42%, Top-3 Accuracy: 11.84%
# Epoch [52/300], Avg Loss: 2.6138, Top-1 Accuracy: 7.35%, Top-3 Accuracy: 12.11%
# Epoch [53/300], Avg Loss: 2.5789, Top-1 Accuracy: 7.60%, Top-3 Accuracy: 12.61%
# Epoch [54/300], Avg Loss: 2.5433, Top-1 Accuracy: 7.43%, Top-3 Accuracy: 12.75%
# Epoch [55/300], Avg Loss: 2.5341, Top-1 Accuracy: 7.38%, Top-3 Accuracy: 12.22%
# Epoch [56/300], Avg Loss: 2.5013, Top-1 Accuracy: 7.76%, Top-3 Accuracy: 12.32%
# Epoch [57/300], Avg Loss: 2.4988, Top-1 Accuracy: 7.38%, Top-3 Accuracy: 12.25%
# Epoch [58/300], Avg Loss: 2.4869, Top-1 Accuracy: 7.69%, Top-3 Accuracy: 12.47%
# Epoch [59/300], Avg Loss: 2.4650, Top-1 Accuracy: 7.42%, Top-3 Accuracy: 12.80%
# Epoch [60/300], Avg Loss: 2.4570, Top-1 Accuracy: 8.01%, Top-3 Accuracy: 12.76%
# Epoch [61/300], Avg Loss: 2.4461, Top-1 Accuracy: 7.81%, Top-3 Accuracy: 12.47%
# Epoch [62/300], Avg Loss: 2.4110, Top-1 Accuracy: 7.81%, Top-3 Accuracy: 12.42%
# Epoch [63/300], Avg Loss: 2.3928, Top-1 Accuracy: 7.62%, Top-3 Accuracy: 12.61%
# Epoch [64/300], Avg Loss: 2.4050, Top-1 Accuracy: 7.98%, Top-3 Accuracy: 12.76%
# Epoch [65/300], Avg Loss: 2.4198, Top-1 Accuracy: 7.62%, Top-3 Accuracy: 12.39%
# Epoch [66/300], Avg Loss: 2.3561, Top-1 Accuracy: 8.00%, Top-3 Accuracy: 12.51%
# Epoch [67/300], Avg Loss: 2.3742, Top-1 Accuracy: 7.55%, Top-3 Accuracy: 12.59%
# Epoch [68/300], Avg Loss: 2.3767, Top-1 Accuracy: 8.12%, Top-3 Accuracy: 13.34%
# Epoch [69/300], Avg Loss: 2.3547, Top-1 Accuracy: 7.96%, Top-3 Accuracy: 12.78%
# Epoch [70/300], Avg Loss: 2.3115, Top-1 Accuracy: 8.17%, Top-3 Accuracy: 13.21%
# Epoch [71/300], Avg Loss: 2.2912, Top-1 Accuracy: 8.56%, Top-3 Accuracy: 13.17%
# Epoch [72/300], Avg Loss: 2.3430, Top-1 Accuracy: 8.34%, Top-3 Accuracy: 12.85%
# Epoch [73/300], Avg Loss: 2.2964, Top-1 Accuracy: 7.93%, Top-3 Accuracy: 13.14%
# Epoch [74/300], Avg Loss: 2.2781, Top-1 Accuracy: 8.39%, Top-3 Accuracy: 13.12%
# Epoch [75/300], Avg Loss: 2.2887, Top-1 Accuracy: 8.39%, Top-3 Accuracy: 13.07%
# Epoch [76/300], Avg Loss: 2.2176, Top-1 Accuracy: 8.59%, Top-3 Accuracy: 13.43%
# Epoch [77/300], Avg Loss: 2.2480, Top-1 Accuracy: 8.63%, Top-3 Accuracy: 13.67%
# Epoch [78/300], Avg Loss: 2.2408, Top-1 Accuracy: 8.71%, Top-3 Accuracy: 13.53%
# Epoch [79/300], Avg Loss: 2.2446, Top-1 Accuracy: 8.66%, Top-3 Accuracy: 13.60%
# Epoch [80/300], Avg Loss: 2.2195, Top-1 Accuracy: 8.65%, Top-3 Accuracy: 13.75%
# Epoch [81/300], Avg Loss: 2.1990, Top-1 Accuracy: 8.34%, Top-3 Accuracy: 13.10%
# Epoch [82/300], Avg Loss: 2.1965, Top-1 Accuracy: 8.12%, Top-3 Accuracy: 13.58%
# Epoch [83/300], Avg Loss: 2.2087, Top-1 Accuracy: 8.66%, Top-3 Accuracy: 13.87%
# Epoch [84/300], Avg Loss: 2.2038, Top-1 Accuracy: 8.87%, Top-3 Accuracy: 13.84%
# Epoch [85/300], Avg Loss: 2.1849, Top-1 Accuracy: 8.92%, Top-3 Accuracy: 13.98%
# Epoch [86/300], Avg Loss: 2.1743, Top-1 Accuracy: 8.82%, Top-3 Accuracy: 13.75%
# Epoch [87/300], Avg Loss: 2.1524, Top-1 Accuracy: 8.87%, Top-3 Accuracy: 13.98%
# Epoch [88/300], Avg Loss: 2.1779, Top-1 Accuracy: 8.61%, Top-3 Accuracy: 13.43%
# Epoch [89/300], Avg Loss: 2.1673, Top-1 Accuracy: 8.68%, Top-3 Accuracy: 13.87%
# Epoch [90/300], Avg Loss: 2.1132, Top-1 Accuracy: 8.75%, Top-3 Accuracy: 13.75%
# Epoch [91/300], Avg Loss: 2.0947, Top-1 Accuracy: 8.85%, Top-3 Accuracy: 13.41%
# Epoch [92/300], Avg Loss: 2.1168, Top-1 Accuracy: 8.58%, Top-3 Accuracy: 13.60%
# Epoch [93/300], Avg Loss: 2.1103, Top-1 Accuracy: 8.99%, Top-3 Accuracy: 14.25%
# Epoch [94/300], Avg Loss: 2.1084, Top-1 Accuracy: 9.00%, Top-3 Accuracy: 14.40%
# Epoch [95/300], Avg Loss: 2.0956, Top-1 Accuracy: 9.24%, Top-3 Accuracy: 13.99%
# Epoch [96/300], Avg Loss: 2.0944, Top-1 Accuracy: 8.53%, Top-3 Accuracy: 13.91%
# Epoch [97/300], Avg Loss: 2.0793, Top-1 Accuracy: 9.06%, Top-3 Accuracy: 13.96%
# Epoch [98/300], Avg Loss: 2.0709, Top-1 Accuracy: 9.74%, Top-3 Accuracy: 14.27%
# Epoch [99/300], Avg Loss: 2.0379, Top-1 Accuracy: 9.50%, Top-3 Accuracy: 14.33%
# Epoch [100/300], Avg Loss: 2.0597, Top-1 Accuracy: 9.35%, Top-3 Accuracy: 14.30%
# Epoch [101/300], Avg Loss: 2.0658, Top-1 Accuracy: 9.12%, Top-3 Accuracy: 13.87%
# Epoch [102/300], Avg Loss: 2.0665, Top-1 Accuracy: 9.16%, Top-3 Accuracy: 14.49%
# Epoch [103/300], Avg Loss: 2.0551, Top-1 Accuracy: 8.66%, Top-3 Accuracy: 13.77%
# Epoch [104/300], Avg Loss: 2.0307, Top-1 Accuracy: 9.00%, Top-3 Accuracy: 14.39%
# Epoch [105/300], Avg Loss: 2.0307, Top-1 Accuracy: 8.97%, Top-3 Accuracy: 14.32%
# Epoch [106/300], Avg Loss: 2.0028, Top-1 Accuracy: 9.14%, Top-3 Accuracy: 14.57%
# Epoch [107/300], Avg Loss: 2.0187, Top-1 Accuracy: 8.99%, Top-3 Accuracy: 14.57%
# Epoch [108/300], Avg Loss: 2.0180, Top-1 Accuracy: 9.43%, Top-3 Accuracy: 14.32%
# Epoch [109/300], Avg Loss: 1.9986, Top-1 Accuracy: 9.36%, Top-3 Accuracy: 14.42%
# Epoch [110/300], Avg Loss: 1.9922, Top-1 Accuracy: 9.50%, Top-3 Accuracy: 14.44%
# Epoch [111/300], Avg Loss: 2.0108, Top-1 Accuracy: 9.72%, Top-3 Accuracy: 14.47%
# Epoch [112/300], Avg Loss: 1.9539, Top-1 Accuracy: 9.31%, Top-3 Accuracy: 14.11%
# Epoch [113/300], Avg Loss: 2.0096, Top-1 Accuracy: 9.57%, Top-3 Accuracy: 14.47%
# Epoch [114/300], Avg Loss: 1.9783, Top-1 Accuracy: 9.29%, Top-3 Accuracy: 14.39%
# Epoch [115/300], Avg Loss: 2.0000, Top-1 Accuracy: 9.35%, Top-3 Accuracy: 14.76%
# Epoch [116/300], Avg Loss: 1.9762, Top-1 Accuracy: 9.65%, Top-3 Accuracy: 14.52%
# Epoch [117/300], Avg Loss: 1.9507, Top-1 Accuracy: 9.40%, Top-3 Accuracy: 14.57%
# Epoch [118/300], Avg Loss: 1.9638, Top-1 Accuracy: 9.43%, Top-3 Accuracy: 14.37%
# Epoch [119/300], Avg Loss: 1.9502, Top-1 Accuracy: 9.40%, Top-3 Accuracy: 14.54%
# Epoch [120/300], Avg Loss: 1.9451, Top-1 Accuracy: 9.57%, Top-3 Accuracy: 14.68%
# Epoch [121/300], Avg Loss: 1.9326, Top-1 Accuracy: 9.48%, Top-3 Accuracy: 14.73%
# Epoch [122/300], Avg Loss: 1.9734, Top-1 Accuracy: 9.36%, Top-3 Accuracy: 14.52%
# Epoch [123/300], Avg Loss: 1.9171, Top-1 Accuracy: 9.94%, Top-3 Accuracy: 14.81%
# Epoch [124/300], Avg Loss: 1.9307, Top-1 Accuracy: 9.69%, Top-3 Accuracy: 14.76%
# Epoch [125/300], Avg Loss: 1.9196, Top-1 Accuracy: 9.24%, Top-3 Accuracy: 14.51%
# Epoch [126/300], Avg Loss: 1.8983, Top-1 Accuracy: 9.62%, Top-3 Accuracy: 14.45%
# Epoch [127/300], Avg Loss: 1.9016, Top-1 Accuracy: 9.29%, Top-3 Accuracy: 15.00%
# Epoch [128/300], Avg Loss: 1.9288, Top-1 Accuracy: 9.72%, Top-3 Accuracy: 14.66%
# Epoch [129/300], Avg Loss: 1.8927, Top-1 Accuracy: 9.84%, Top-3 Accuracy: 14.73%
# Epoch [130/300], Avg Loss: 1.9047, Top-1 Accuracy: 9.50%, Top-3 Accuracy: 14.54%
# Epoch [131/300], Avg Loss: 1.9038, Top-1 Accuracy: 9.77%, Top-3 Accuracy: 14.88%
# Epoch [132/300], Avg Loss: 1.8857, Top-1 Accuracy: 9.31%, Top-3 Accuracy: 14.71%
# Epoch [133/300], Avg Loss: 1.8977, Top-1 Accuracy: 9.53%, Top-3 Accuracy: 14.93%
# Epoch [134/300], Avg Loss: 1.8880, Top-1 Accuracy: 9.77%, Top-3 Accuracy: 14.88%
# Epoch [135/300], Avg Loss: 1.8684, Top-1 Accuracy: 9.91%, Top-3 Accuracy: 15.04%
# Epoch [136/300], Avg Loss: 1.9030, Top-1 Accuracy: 9.41%, Top-3 Accuracy: 14.81%
# Epoch [137/300], Avg Loss: 1.8633, Top-1 Accuracy: 9.99%, Top-3 Accuracy: 15.09%
# Epoch [138/300], Avg Loss: 1.8479, Top-1 Accuracy: 9.58%, Top-3 Accuracy: 15.21%
# Epoch [139/300], Avg Loss: 1.8382, Top-1 Accuracy: 9.23%, Top-3 Accuracy: 14.83%
# Epoch [140/300], Avg Loss: 1.8602, Top-1 Accuracy: 9.99%, Top-3 Accuracy: 15.19%
# Epoch [141/300], Avg Loss: 1.8687, Top-1 Accuracy: 9.91%, Top-3 Accuracy: 14.92%
# Epoch [142/300], Avg Loss: 1.8691, Top-1 Accuracy: 10.20%, Top-3 Accuracy: 15.34%
# Epoch [143/300], Avg Loss: 1.8962, Top-1 Accuracy: 9.62%, Top-3 Accuracy: 14.69%
# Epoch [144/300], Avg Loss: 1.8539, Top-1 Accuracy: 10.20%, Top-3 Accuracy: 15.26%
# Epoch [145/300], Avg Loss: 1.8345, Top-1 Accuracy: 10.03%, Top-3 Accuracy: 15.12%
# Epoch [146/300], Avg Loss: 1.8307, Top-1 Accuracy: 10.01%, Top-3 Accuracy: 15.07%
# Epoch [147/300], Avg Loss: 1.8320, Top-1 Accuracy: 10.11%, Top-3 Accuracy: 15.34%
# Epoch [148/300], Avg Loss: 1.8785, Top-1 Accuracy: 10.11%, Top-3 Accuracy: 14.97%
# Epoch [149/300], Avg Loss: 1.8227, Top-1 Accuracy: 10.10%, Top-3 Accuracy: 15.46%
# Epoch [150/300], Avg Loss: 1.8575, Top-1 Accuracy: 9.81%, Top-3 Accuracy: 15.21%
# Epoch [151/300], Avg Loss: 1.8313, Top-1 Accuracy: 9.99%, Top-3 Accuracy: 15.09%
# Epoch [152/300], Avg Loss: 1.8315, Top-1 Accuracy: 10.05%, Top-3 Accuracy: 15.43%
# Epoch [153/300], Avg Loss: 1.7988, Top-1 Accuracy: 9.98%, Top-3 Accuracy: 15.17%
# Epoch [154/300], Avg Loss: 1.8336, Top-1 Accuracy: 10.03%, Top-3 Accuracy: 15.33%
# Epoch [155/300], Avg Loss: 1.8161, Top-1 Accuracy: 9.53%, Top-3 Accuracy: 15.34%
# Epoch [156/300], Avg Loss: 1.7707, Top-1 Accuracy: 9.82%, Top-3 Accuracy: 15.05%
# Epoch [157/300], Avg Loss: 1.8067, Top-1 Accuracy: 10.32%, Top-3 Accuracy: 15.68%
# Epoch [158/300], Avg Loss: 1.7940, Top-1 Accuracy: 9.67%, Top-3 Accuracy: 14.93%
# Epoch [159/300], Avg Loss: 1.7804, Top-1 Accuracy: 10.08%, Top-3 Accuracy: 15.51%
# Epoch [160/300], Avg Loss: 1.7671, Top-1 Accuracy: 10.01%, Top-3 Accuracy: 15.31%
# Epoch [161/300], Avg Loss: 1.7747, Top-1 Accuracy: 10.51%, Top-3 Accuracy: 15.77%
# Epoch [162/300], Avg Loss: 1.7937, Top-1 Accuracy: 10.25%, Top-3 Accuracy: 15.63%
# Epoch [163/300], Avg Loss: 1.7962, Top-1 Accuracy: 10.08%, Top-3 Accuracy: 15.39%
# Epoch [164/300], Avg Loss: 1.7696, Top-1 Accuracy: 10.51%, Top-3 Accuracy: 15.27%
# Epoch [165/300], Avg Loss: 1.7816, Top-1 Accuracy: 10.06%, Top-3 Accuracy: 15.22%
# Epoch [166/300], Avg Loss: 1.7810, Top-1 Accuracy: 10.39%, Top-3 Accuracy: 15.51%
# Epoch [167/300], Avg Loss: 1.7702, Top-1 Accuracy: 9.88%, Top-3 Accuracy: 15.27%
# Epoch [168/300], Avg Loss: 1.7307, Top-1 Accuracy: 10.23%, Top-3 Accuracy: 16.01%
# Epoch [169/300], Avg Loss: 1.7769, Top-1 Accuracy: 10.40%, Top-3 Accuracy: 15.50%
# Epoch [170/300], Avg Loss: 1.7475, Top-1 Accuracy: 9.98%, Top-3 Accuracy: 15.62%
# Epoch [171/300], Avg Loss: 1.7665, Top-1 Accuracy: 10.17%, Top-3 Accuracy: 15.48%
# Epoch [172/300], Avg Loss: 1.7621, Top-1 Accuracy: 10.17%, Top-3 Accuracy: 15.58%
# Epoch [173/300], Avg Loss: 1.7723, Top-1 Accuracy: 10.13%, Top-3 Accuracy: 15.48%
# Epoch [174/300], Avg Loss: 1.7759, Top-1 Accuracy: 10.01%, Top-3 Accuracy: 15.68%
# Epoch [175/300], Avg Loss: 1.7300, Top-1 Accuracy: 10.52%, Top-3 Accuracy: 15.62%
# Epoch [176/300], Avg Loss: 1.7536, Top-1 Accuracy: 10.34%, Top-3 Accuracy: 15.56%
# Epoch [177/300], Avg Loss: 1.7294, Top-1 Accuracy: 10.27%, Top-3 Accuracy: 15.58%
# Epoch [178/300], Avg Loss: 1.7179, Top-1 Accuracy: 10.25%, Top-3 Accuracy: 15.45%
# Epoch [179/300], Avg Loss: 1.7624, Top-1 Accuracy: 10.47%, Top-3 Accuracy: 15.86%
# Epoch [180/300], Avg Loss: 1.7155, Top-1 Accuracy: 10.64%, Top-3 Accuracy: 15.50%
# Epoch [181/300], Avg Loss: 1.7450, Top-1 Accuracy: 10.25%, Top-3 Accuracy: 15.55%
# Epoch [182/300], Avg Loss: 1.7473, Top-1 Accuracy: 10.25%, Top-3 Accuracy: 15.86%
# Epoch [183/300], Avg Loss: 1.7021, Top-1 Accuracy: 10.66%, Top-3 Accuracy: 15.72%
# Epoch [184/300], Avg Loss: 1.7591, Top-1 Accuracy: 10.42%, Top-3 Accuracy: 15.70%
# Epoch [185/300], Avg Loss: 1.6979, Top-1 Accuracy: 10.44%, Top-3 Accuracy: 15.87%
# Epoch [186/300], Avg Loss: 1.7549, Top-1 Accuracy: 10.06%, Top-3 Accuracy: 15.38%
# Epoch [187/300], Avg Loss: 1.7284, Top-1 Accuracy: 10.59%, Top-3 Accuracy: 15.91%
# Epoch [188/300], Avg Loss: 1.6922, Top-1 Accuracy: 10.25%, Top-3 Accuracy: 15.56%
# Epoch [189/300], Avg Loss: 1.6878, Top-1 Accuracy: 10.27%, Top-3 Accuracy: 15.72%
# Epoch [190/300], Avg Loss: 1.7442, Top-1 Accuracy: 10.10%, Top-3 Accuracy: 15.74%
# Epoch [191/300], Avg Loss: 1.6886, Top-1 Accuracy: 10.29%, Top-3 Accuracy: 16.21%
# Epoch [192/300], Avg Loss: 1.7416, Top-1 Accuracy: 10.39%, Top-3 Accuracy: 15.86%
# Epoch [193/300], Avg Loss: 1.7082, Top-1 Accuracy: 10.70%, Top-3 Accuracy: 15.91%
# Epoch [194/300], Avg Loss: 1.7344, Top-1 Accuracy: 10.75%, Top-3 Accuracy: 16.15%
# Epoch [195/300], Avg Loss: 1.6730, Top-1 Accuracy: 10.20%, Top-3 Accuracy: 15.82%
# Epoch [196/300], Avg Loss: 1.6959, Top-1 Accuracy: 10.54%, Top-3 Accuracy: 15.91%
# Epoch [197/300], Avg Loss: 1.7236, Top-1 Accuracy: 10.87%, Top-3 Accuracy: 16.27%
# Epoch [198/300], Avg Loss: 1.7143, Top-1 Accuracy: 10.18%, Top-3 Accuracy: 15.80%
# Epoch [199/300], Avg Loss: 1.6935, Top-1 Accuracy: 10.70%, Top-3 Accuracy: 16.18%
# Epoch [200/300], Avg Loss: 1.7230, Top-1 Accuracy: 10.88%, Top-3 Accuracy: 15.92%
# Epoch [201/300], Avg Loss: 1.6835, Top-1 Accuracy: 10.95%, Top-3 Accuracy: 15.99%
# Epoch [202/300], Avg Loss: 1.6993, Top-1 Accuracy: 10.54%, Top-3 Accuracy: 15.75%
# Epoch [203/300], Avg Loss: 1.6840, Top-1 Accuracy: 10.70%, Top-3 Accuracy: 15.97%
# Epoch [204/300], Avg Loss: 1.6676, Top-1 Accuracy: 10.78%, Top-3 Accuracy: 15.92%
# Epoch [205/300], Avg Loss: 1.7012, Top-1 Accuracy: 10.99%, Top-3 Accuracy: 16.15%
# Epoch [206/300], Avg Loss: 1.6803, Top-1 Accuracy: 10.66%, Top-3 Accuracy: 15.75%
# Epoch [207/300], Avg Loss: 1.6708, Top-1 Accuracy: 10.76%, Top-3 Accuracy: 16.15%
# Epoch [208/300], Avg Loss: 1.6955, Top-1 Accuracy: 10.66%, Top-3 Accuracy: 15.94%
# Epoch [209/300], Avg Loss: 1.6861, Top-1 Accuracy: 10.29%, Top-3 Accuracy: 15.68%
# Epoch [210/300], Avg Loss: 1.6289, Top-1 Accuracy: 10.95%, Top-3 Accuracy: 16.20%
# Epoch [211/300], Avg Loss: 1.6411, Top-1 Accuracy: 10.83%, Top-3 Accuracy: 16.06%
# Epoch [212/300], Avg Loss: 1.6459, Top-1 Accuracy: 10.85%, Top-3 Accuracy: 16.30%
# Epoch [213/300], Avg Loss: 1.6679, Top-1 Accuracy: 10.34%, Top-3 Accuracy: 15.92%
# Epoch [214/300], Avg Loss: 1.6811, Top-1 Accuracy: 10.71%, Top-3 Accuracy: 15.91%
# Epoch [215/300], Avg Loss: 1.6735, Top-1 Accuracy: 10.73%, Top-3 Accuracy: 16.25%
# Epoch [216/300], Avg Loss: 1.6597, Top-1 Accuracy: 10.66%, Top-3 Accuracy: 16.06%
# Epoch [217/300], Avg Loss: 1.6653, Top-1 Accuracy: 10.80%, Top-3 Accuracy: 15.99%
# Epoch [218/300], Avg Loss: 1.6634, Top-1 Accuracy: 10.68%, Top-3 Accuracy: 15.96%
# Epoch [219/300], Avg Loss: 1.6693, Top-1 Accuracy: 10.29%, Top-3 Accuracy: 16.28%
# Epoch [220/300], Avg Loss: 1.6094, Top-1 Accuracy: 10.95%, Top-3 Accuracy: 16.28%
# Epoch [221/300], Avg Loss: 1.6197, Top-1 Accuracy: 10.13%, Top-3 Accuracy: 16.40%
# Epoch [222/300], Avg Loss: 1.6852, Top-1 Accuracy: 10.39%, Top-3 Accuracy: 15.82%
# Epoch [223/300], Avg Loss: 1.6174, Top-1 Accuracy: 10.76%, Top-3 Accuracy: 16.38%
# Epoch [224/300], Avg Loss: 1.6281, Top-1 Accuracy: 10.85%, Top-3 Accuracy: 16.04%
# Epoch [225/300], Avg Loss: 1.6160, Top-1 Accuracy: 10.83%, Top-3 Accuracy: 16.11%
# Epoch [226/300], Avg Loss: 1.6123, Top-1 Accuracy: 10.52%, Top-3 Accuracy: 16.45%
# Epoch [227/300], Avg Loss: 1.6307, Top-1 Accuracy: 10.88%, Top-3 Accuracy: 16.38%
# Epoch [228/300], Avg Loss: 1.6164, Top-1 Accuracy: 10.49%, Top-3 Accuracy: 16.20%
# Epoch [229/300], Avg Loss: 1.6503, Top-1 Accuracy: 11.00%, Top-3 Accuracy: 16.08%
# Epoch [230/300], Avg Loss: 1.6460, Top-1 Accuracy: 10.34%, Top-3 Accuracy: 16.01%
# Early stopping triggered
# Final Top-1 Accuracy: 10.34%
# Final Top-3 Accuracy: 16.01%
# Model training complete and saved!
